# %%
import random
list1=["Rock","Paper","Scissor"]
while True:
    user_choose=int(input('''
    Note:Only press 1 or 2 
    Play--> 
    -----Exit'''
                      ))
    
    
    if user_choose==1:
        for i in range(1):
            user_choose=input('''
    -----Game Start------
    Note:=>Plase select only 1 or 2 or 3
    1.Rock
    2.Scissors
    3.Paper
    
    You selected-->''')
            if user_choose==1:
                
                U_select="Rock"
            elif user_choose==2:
                U_select="Scissors"
            else:
                U_select="Paper"
            comp_select=random.choice(list1) 
            if comp_select==U_select:
                print("Game Draw!")
                print("You     : ",U_select)
                print("Computer: ",comp_select)
            elif ((comp_select=="Rock"and U_select=="Scissors") or(comp_select=="Scessors"and U_Select=="Paper")
                or (comp_select== "Paper" and U_select=="Rock")):
                print("Computer Win!")
                print("You     : ",U_select)
                print("Computer: ",comp_select)
            else: 
                print("You Win!")
                print("You     : ",U_select)
                print("Computer: ",comp_select)
    else:
        break

# %%
l=["rock","paper","scissors"]
while True:
    user_count=0
    comp_count=0
    
    User_choice = int(input('''
    Game Start.....
    1. Play | Yes
    2. No | Exit
    note:press only 1 or 2
    '''))
     
    if User_choice==1:
        for i in range(1,6):
            user_input=int(input('''
1. Rock
2. Scissors
3. paper
note:press only 1 or 2 or 3
        you select:- '''))
            print()
            if user_input==1:
                u_select="rock"
            elif user_input==2:
                u_select="scissors"
            elif user_input==3:
                u_select="paper"
            comp_select=random.choice(l)
            if u_select==comp_select:
                print("Game Draw!")
                print("You Selected:",u_select)
                print("Comuter Selected:-",comp_select)
                user_count=user_count+1
                comp_count=comp_count+1
            elif ((u_select=="rock"and comp_select=="scissors") or(u_select=="paper"and comp_select=="rock")
                  or(u_select=="scissors"and comp_select=="paper")):
                print("You win!")
                print("You Selected:-",u_select)
                print("Comuter Selected:-",comp_select)
                user_count=user_count+1
            else:
                print("Computer Win!")
                print("You Selected:-",u_select)
                print("Comuter Selected:-",comp_select)
                comp_count=comp_count+1
                print()
        if comp_count==user_count:
            print("Finally Game is Draw!")
            print("Computer Score:=",comp_count)
            print("User Score:=",user_count)
        elif comp_count>user_count:
            print("Finally Computer Win!")
            print("Computer Score:=",comp_count)
            print("User Score:=",user_count)
        else:
            print(" Finally You Win!")
            print("Computer Score:=",comp_count)
            print("User Score:=",user_count)
    else:
        break

# %%
print("You:",user_choose)
        comp_choose=random.choice(list1)
        print("Computer",comp_choose)
